# %% [markdown]
# ## Hierarchical Clustering

# %% [markdown]
# Hierarchical Clustering
# - An agglomerative approach
#     - Find closest two things
#     - Put them together
#     - Find next closest
# - Requires
#     - A defined distance
#     - A merging approach
# - Produces
#     - A tree showing how close things are to each other

# %%
set.seed(1234)
par(mar=c(0,0,0,0))
x <- rnorm(12, mean = rep(1:3, each = 4), sd = 0.2)
y <- rnorm(12, mean = rep(c(1,2,1), each = 4), sd = 0.2)
plot(x, y, col = 'blue', pch = 19, cex = 2)
text(x + 0.05, y + 0.05, labels = as.character(1:12))
# Out:
# plot without title

# %%
dataFrame <- data.frame(x = x, y = y)
dataFrame
# Out:
#    x         y
# 1  0.7585869 0.8447492
# 2  1.0554858 1.0128918
# 3  1.2168882 1.1918988
# 4  0.5308605 0.9779429
# 5  2.0858249 1.8977981
# 6  2.1012112 1.8177609
# 7  1.8850520 1.8325657
# 8  1.8906736 2.4831670
# 9  2.8871096 1.0268176
# 10 2.8219924 0.9018628
# 11 2.9045615 0.9118904
# 12 2.8003227 1.0919179

# %%
distxy <- dist(dataFrame)
dist(dataFrame)
# Out:
#             1          2          3          4          5          6          7
# 2  0.34120511
# 3  0.57493739 0.24102750
# 4  0.26381786 0.52578819 0.71861759
# 5  1.69424700 1.35818182 1.11952883 1.80666768
# 6  1.65812902 1.31960442 1.08338841 1.78081321 0.08150268
# 7  1.49823399 1.16620981 0.92568723 1.60131659 0.21110433 0.21666557
# 8  1.99149025 1.69093111 1.45648906 2.02849490 0.61704200 0.69791931 0.65062566
# 9  2.13629539 1.83167669 1.67835968 2.35675598 1.18349654 1.11500116 1.28582631
# 10 2.06419586 1.76999236 1.63109790 2.29239480 1.23847877 1.16550201 1.32063059
# 11 2.14702468 1.85183204 1.71074417 2.37461984 1.28153948 1.21077373 1.37369662
# 12 2.05664233 1.74662555 1.58658782 2.27232243 1.07700974 1.00777231 1.17740375
#             8          9         10         11
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9  1.76460709
# 10 1.83517785 0.14090406
# 11 1.86999431 0.11624471 0.08317570
# 12 1.66223814 0.10848966 0.19128645 0.20802789

# %%
#?dist

# %%
hClustering <- hclust(distxy)
plot(hClustering)
# Out:
# Plot with title “Cluster Dendrogram”

# %%
# ?hclust

# %% [markdown]
# 缺点：我们无法得知这12个点，到底可以分为几个clusters。可以画横线来判断，如
# - y=2 --> 2 clusters
# - y = 1.5 --> 3
# - y = 0.5 --> bla bla bla
#
# 于是我们得到了下面的解决方案

# %%
# myplclust.R
#' plclust in colour
#' 
#' Modifiction of plclust for plotting hclust objects in *in colour*!
#' 
#' @param hclust hclust object
#' @param labels a character vector of labels of the leaves of the tree
#' @param lab.col colour for the labels; NA=default device foreground colour
#' @param hang as in \code{\link{hclust}} & \code{\link{plclust}}
#' @param xlab title for x-axis (defaults to no title)
#' @param sub subtitle (defualts to no subtitle)
#' @param ... further arguments passed to \code{\link{plot}}
#' @author Eva KF Chan
#' 
#' @examples
#' data(iris)
#' hc <- hclust( dist(iris[,1:4]) )
#' myplclust(hc, labels=iris$Species,lab.col=as.numeric(iris$Species))
#' 
#' 
myplclust <- function( hclust, labels=hclust$labels, lab.col=rep(1,length(hclust$labels)), hang=0.1, xlab="", sub="", ...){
 ## modifiction of plclust for plotting hclust objects *in colour*!
 ## Copyright Eva KF Chan 2009
 ## Arguments:
 ##    hclust:    hclust object
 ##    lab:        a character vector of labels of the leaves of the tree
 ##    lab.col:    colour for the labels; NA=default device foreground colour
 ##    hang:     as in hclust & plclust
 ## Side effect:
 ##    A display of hierarchical cluster with coloured leaf labels.
    y <- rep(hclust$height,2)
    x <- as.numeric(hclust$merge)
    y <- y[which(x<0)]
    x <- x[which(x<0)]
    x <- abs(x)
    y <- y[order(x)]
    x <- x[order(x)]
    plot( hclust, labels=FALSE, hang=hang, xlab=xlab, sub=sub, ... )
    text( x=x, y=y[hclust$order]-(max(hclust$height)*hang), labels=labels[hclust$order], col=lab.col[hclust$order], srt=90, adj=c(1,0.5), xpd=NA, ... )
}

# %%
myplclust(hClustering, lab = rep(1:3, each = 4), lab.col=rep(1:3, each = 4))
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ### Merging points通常有2种approach, complete 和 average
# - complete: 寻找距离最远的两个点之间的距离
# - average: 寻找各个点之间的平均距离
# 2种方法各有特点，在实际做项目时建议都尝试一下

# %% [markdown]
# ### heatmap()

# %%
set.seed(143)
dataMatrix <- as.matrix(dataFrame)[sample(1:12),]
heatmap(dataMatrix)
# Out:
# plot without title

# %%
sample(1:12)
# Out:
#  [1]  6  7  9 12  3 11  5  2 10  8  4  1

# %%
#?as.matrix

# %% [markdown]
# ## K-Means Clustering & Dimension Reduction

# %%
set.seed(1234)
par(mar=c(0,0,0,0))
x <- rnorm(12, mean = rep(1:3, each = 4), sd = 0.2)
y <- rnorm(12, mean = rep(c(1,2,1), each = 4), sd = 0.2)
plot(x, y, col = 'blue', pch = 19, cex = 2)
text(x + 0.05, y + 0.05, labels = as.character(1:12))
# Out:
# plot without title

# %%
dataFrame <- data.frame(x, y)
kmeansObj <- kmeans(dataFrame, centers = 3)
names(kmeansObj)
# Out:
# [1] "cluster"      "centers"      "totss"        "withinss"     "tot.withinss"
# [6] "betweenss"    "size"         "iter"         "ifault"

# %%
kmeansObj$cluster
# Out:
#  [1] 3 1 1 3 2 2 2 2 2 2 2 2

# %%
par(mar = rep(0.2, 4))
plot(x, y , col = kmeansObj$cluster, pch = 19, cex = 2)
points(kmeansObj$centers, col = c(1:3), pch = 3, cex = 3, lwd = 3)
# Out:
# plot without title

# %%
set.seed(1234)
dataMatrix <- as.matrix(dataFrame)[sample(1:12), ]
kmeansObj2 <- kmeans(dataMatrix, centers = 3)
par(mfrow = c(1,2), mar = c(2, 4, 0.1, 0.1))
image(
    t(dataMatrix)[, nrow(dataMatrix):1]
    , yaxt = 'n'
)
image(
    t(dataMatrix)[,order(kmeansObj$cluster)]
    , yaxt = 'n'
)
# Out:
# plot without title

# %% [markdown]
# ## Principal Components Analysis (PCA) and Singular Value Decomposition

# %%
set.seed(12345)
par(mar = rep(0.2, 4))
dataMatrix <- matrix(rnorm(400), nrow = 40)
image(1:10, 1:40, t(dataMatrix))[, nrow(dataMatrix):1]
# it looks pretty noisy
# Out:
# NULL
# plot without title

# %%
par(mar = rep(0.2, 4))
heatmap(dataMatrix) # still no interesting pattern there
# Out:
# plot without title

# %%
# What if we add a pattern?
set.seed(678910)
for (i in 1:40){
    # flip a cion
    coinFlip <- rbinom(1, size = 1, prob = 0.5)
    # if coin is head, add a common pattern to that row
    if (coinFlip){
        dataMatrix[i, ] <- dataMatrix[i, ] + rep(c(0,3), each = 5)
    }
}

# %%
par(mar = rep(0.2, 4))
heatmap(dataMatrix) 
# and now the right hand five columns are a little more red, indicating they have lower value
# Out:
# plot without title

# %%
par(mar = rep(0.2, 4))
heatmap(dataMatrix)
# Out:
# plot without title

# %%
hh <- hclust(dist(dataMatrix))
dataMatrixOrdered <- dataMatrix[hh$order, ]
par(mfrow = c(1,3))
image(
    t(dataMatrixOrdered)[, nrow(dataMatrixOrdered):1]
)
plot(rowMeans(dataMatrixOrdered), 40:1, , xlab = 'Row Mean', ylab = 'Row', pch = 19)
plot(colMeans(dataMatrixOrdered), xlab = 'Column', ylab = 'Column Mean', pch = 19)
# Out:
# plot without title

# %% [markdown]
# ### Related Problems
# You have multivatiate variables $X_1, \ldots , X_{n}$ so that $X_{1} = \left( X_{11}, \ldots , X_{1m} \right) $, then you have 2 goals
# - **statistical goal**: Find a new set of multivariate variables that are uncorrelated and explain as much variance as possible
# - **data compression goal**: If you put all the variables together in one matrix, find the best matrix created with fewer variables (lower rank) that explains the original data

# %% [markdown]
# ### SVD
